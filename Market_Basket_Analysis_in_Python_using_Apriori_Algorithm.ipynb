# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# Dataset

# %%
dataset = [['Milk', 'Eggs', 'Bread', 'Butter'],
           ['Milk', 'Cookies', 'Butter'],
           ['Milk', 'Bread', 'Cookies', 'Eggs', 'Butter'],
           ['Bread', 'Cookies', 'Eggs'],
           ['Bread', 'Cookies', 'Butter'],
           ['Milk', 'Bread', 'Cookies', 'Eggs'],
           ['Milk', 'Bread', 'Butter'],
           ['Milk', 'Eggs', 'Cookies']]

# %% [markdown]
#  Transform the dataset into a one-hot encoded format

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %% [markdown]
# Apply the Apriori algorithm to find frequent itemsets

# %%
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)

# %% [markdown]
#  Generate association rules

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %% [markdown]
# Sort the association rules by confidence in descending order

# %%
rules = rules.sort_values(by=['confidence'], ascending=False)

# %% [markdown]
# Print the frequent itemsets

# %%
print("Frequent Itemsets:")
print(frequent_itemsets)
# Out:
# Frequent Itemsets:
#     support                itemsets
# 0     0.750                 (Bread)
# 1     0.625                (Butter)
# 2     0.750               (Cookies)
# 3     0.625                  (Eggs)
# 4     0.750                  (Milk)
# 5     0.500         (Bread, Butter)
# 6     0.500        (Cookies, Bread)
# 7     0.500           (Bread, Eggs)
# 8     0.500           (Milk, Bread)
# 9     0.375       (Cookies, Butter)
# 10    0.500          (Milk, Butter)
# 11    0.500         (Cookies, Eggs)
# 12    0.500         (Cookies, Milk)
# 13    0.500            (Milk, Eggs)
# 14    0.375   (Milk, Bread, Butter)
# 15    0.375  (Cookies, Bread, Eggs)
# 16    0.375     (Milk, Bread, Eggs)
# 17    0.375   (Cookies, Eggs, Milk)

# %% [markdown]
# Print the association rules

# %%
print("\nAssociation Rules:")
print(rules)
# Out:
# Association Rules:
#          antecedents       consequents  antecedent support  \
# 17            (Eggs)            (Milk)               0.625
# 5             (Eggs)           (Bread)               0.625
# 11          (Butter)            (Milk)               0.625
# 1           (Butter)           (Bread)               0.625
# 13            (Eggs)         (Cookies)               0.625
# 18     (Milk, Bread)          (Butter)               0.500
# 32     (Bread, Eggs)            (Milk)               0.500
# 31      (Milk, Eggs)           (Bread)               0.500
# 30     (Milk, Bread)            (Eggs)               0.500
# 37   (Cookies, Milk)            (Eggs)               0.500
# 38      (Milk, Eggs)         (Cookies)               0.500
# 26     (Bread, Eggs)         (Cookies)               0.500
# 25   (Cookies, Eggs)           (Bread)               0.500
# 24  (Cookies, Bread)            (Eggs)               0.500
# 20   (Bread, Butter)            (Milk)               0.500
# 19    (Milk, Butter)           (Bread)               0.500
# 36   (Cookies, Eggs)            (Milk)               0.500
# 0            (Bread)          (Butter)               0.750
# 15            (Milk)         (Cookies)               0.750
# 14         (Cookies)            (Milk)               0.750
# 12         (Cookies)            (Eggs)               0.750
# 2          (Cookies)           (Bread)               0.750
# 3            (Bread)         (Cookies)               0.750
# 10            (Milk)          (Butter)               0.750
# 16            (Milk)            (Eggs)               0.750
# 4            (Bread)            (Eggs)               0.750
# 7            (Bread)            (Milk)               0.750
# 6             (Milk)           (Bread)               0.750
# 29            (Eggs)  (Cookies, Bread)               0.625
# 35            (Eggs)     (Milk, Bread)               0.625
# 40            (Eggs)   (Cookies, Milk)               0.625
# 23          (Butter)     (Milk, Bread)               0.625
# 9           (Butter)         (Cookies)               0.625
# 39         (Cookies)      (Milk, Eggs)               0.750
# 21            (Milk)   (Bread, Butter)               0.750
# 34           (Bread)      (Milk, Eggs)               0.750
# 33            (Milk)     (Bread, Eggs)               0.750
# 28           (Bread)   (Cookies, Eggs)               0.750
# 27         (Cookies)     (Bread, Eggs)               0.750
# 22           (Bread)    (Milk, Butter)               0.750
# 8          (Cookies)          (Butter)               0.750
# 41            (Milk)   (Cookies, Eggs)               0.750
#
#     consequent support  support  confidence      lift  leverage  conviction
# 17               0.750    0.500    0.800000  1.066667   0.03125       1.250
# 5                0.750    0.500    0.800000  1.066667   0.03125       1.250
# 11               0.750    0.500    0.800000  1.066667   0.03125       1.250
# 1                0.750    0.500    0.800000  1.066667   0.03125       1.250
# 13               0.750    0.500    0.800000  1.066667   0.03125       1.250
# 18               0.625    0.375    0.750000  1.200000   0.06250       1.500
# 32               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 31               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 30               0.625    0.375    0.750000  1.200000   0.06250       1.500
# 37               0.625    0.375    0.750000  1.200000   0.06250       1.500
# 38               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 26               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 25               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 24               0.625    0.375    0.750000  1.200000   0.06250       1.500
# 20               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 19               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 36               0.750    0.375    0.750000  1.000000   0.00000       1.000
# 0                0.625    0.500    0.666667  1.066667   0.03125       1.125
# 15               0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 14               0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 12               0.625    0.500    0.666667  1.066667   0.03125       1.125
# 2                0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 3                0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 10               0.625    0.500    0.666667  1.066667   0.03125       1.125
# 16               0.625    0.500    0.666667  1.066667   0.03125       1.125
# 4                0.625    0.500    0.666667  1.066667   0.03125       1.125
# 7                0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 6                0.750    0.500    0.666667  0.888889  -0.06250       0.750
# 29               0.500    0.375    0.600000  1.200000   0.06250       1.250
# 35               0.500    0.375    0.600000  1.200000   0.06250       1.250
# 40               0.500    0.375    0.600000  1.200000   0.06250       1.250
# 23               0.500    0.375    0.600000  1.200000   0.06250       1.250
# 9                0.750    0.375    0.600000  0.800000  -0.09375       0.625
# 39               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 21               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 34               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 33               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 28               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 27               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 22               0.500    0.375    0.500000  1.000000   0.00000       1.000
# 8                0.625    0.375    0.500000  0.800000  -0.09375       0.750
# 41               0.500    0.375    0.500000  1.000000   0.00000       1.000

# %% [markdown]
# Print additional details of the association rules

# %%
print("\nAssociation Rules Details:")
for i, rule in rules.iterrows():
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    support = rule['support']
    confidence = rule['confidence']
    lift = rule['lift']
    leverage = rule['leverage']
    conviction = rule['conviction']
    print(f"Rule {i+1}:")
    print(f"Antecedents: {antecedents}")
    print(f"Consequents: {consequents}")
    print(f"Support: {support:.3f}")
    print(f"Confidence: {confidence:.3f}")
    print(f"Lift: {lift:.3f}")
    print(f"Leverage: {leverage:.3f}")
    print(f"Conviction: {conviction:.3f}")
    print("\n")
# Out:
# Association Rules Details:
# Rule 18:
# Antecedents: Eggs
# Consequents: Milk
# Support: 0.500
# Confidence: 0.800
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.250
#
#
# Rule 6:
# Antecedents: Eggs
# Consequents: Bread
# Support: 0.500
# Confidence: 0.800
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.250
#
#
# Rule 12:
# Antecedents: Butter
# Consequents: Milk
# Support: 0.500
# Confidence: 0.800
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.250
#
#
# Rule 2:
# Antecedents: Butter
# Consequents: Bread
# Support: 0.500
# Confidence: 0.800
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.250
#
#
# Rule 14:
# Antecedents: Eggs
# Consequents: Cookies
# Support: 0.500
# Confidence: 0.800
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.250
#
#
# Rule 19:
# Antecedents: Milk, Bread
# Consequents: Butter
# Support: 0.375
# Confidence: 0.750
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.500
#
#
# Rule 33:
# Antecedents: Bread, Eggs
# Consequents: Milk
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 32:
# Antecedents: Milk, Eggs
# Consequents: Bread
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 31:
# Antecedents: Milk, Bread
# Consequents: Eggs
# Support: 0.375
# Confidence: 0.750
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.500
#
#
# Rule 38:
# Antecedents: Cookies, Milk
# Consequents: Eggs
# Support: 0.375
# Confidence: 0.750
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.500
#
#
# Rule 39:
# Antecedents: Milk, Eggs
# Consequents: Cookies
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 27:
# Antecedents: Bread, Eggs
# Consequents: Cookies
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 26:
# Antecedents: Cookies, Eggs
# Consequents: Bread
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 25:
# Antecedents: Cookies, Bread
# Consequents: Eggs
# Support: 0.375
# Confidence: 0.750
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.500
#
#
# Rule 21:
# Antecedents: Bread, Butter
# Consequents: Milk
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 20:
# Antecedents: Milk, Butter
# Consequents: Bread
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 37:
# Antecedents: Cookies, Eggs
# Consequents: Milk
# Support: 0.375
# Confidence: 0.750
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 1:
# Antecedents: Bread
# Consequents: Butter
# Support: 0.500
# Confidence: 0.667
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.125
#
#
# Rule 16:
# Antecedents: Milk
# Consequents: Cookies
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 15:
# Antecedents: Cookies
# Consequents: Milk
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 13:
# Antecedents: Cookies
# Consequents: Eggs
# Support: 0.500
# Confidence: 0.667
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.125
#
#
# Rule 3:
# Antecedents: Cookies
# Consequents: Bread
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 4:
# Antecedents: Bread
# Consequents: Cookies
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 11:
# Antecedents: Milk
# Consequents: Butter
# Support: 0.500
# Confidence: 0.667
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.125
#
#
# Rule 17:
# Antecedents: Milk
# Consequents: Eggs
# Support: 0.500
# Confidence: 0.667
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.125
#
#
# Rule 5:
# Antecedents: Bread
# Consequents: Eggs
# Support: 0.500
# Confidence: 0.667
# Lift: 1.067
# Leverage: 0.031
# Conviction: 1.125
#
#
# Rule 8:
# Antecedents: Bread
# Consequents: Milk
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 7:
# Antecedents: Milk
# Consequents: Bread
# Support: 0.500
# Confidence: 0.667
# Lift: 0.889
# Leverage: -0.062
# Conviction: 0.750
#
#
# Rule 30:
# Antecedents: Eggs
# Consequents: Cookies, Bread
# Support: 0.375
# Confidence: 0.600
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.250
#
#
# Rule 36:
# Antecedents: Eggs
# Consequents: Milk, Bread
# Support: 0.375
# Confidence: 0.600
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.250
#
#
# Rule 41:
# Antecedents: Eggs
# Consequents: Cookies, Milk
# Support: 0.375
# Confidence: 0.600
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.250
#
#
# Rule 24:
# Antecedents: Butter
# Consequents: Milk, Bread
# Support: 0.375
# Confidence: 0.600
# Lift: 1.200
# Leverage: 0.062
# Conviction: 1.250
#
#
# Rule 10:
# Antecedents: Butter
# Consequents: Cookies
# Support: 0.375
# Confidence: 0.600
# Lift: 0.800
# Leverage: -0.094
# Conviction: 0.625
#
#
# Rule 40:
# Antecedents: Cookies
# Consequents: Milk, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 22:
# Antecedents: Milk
# Consequents: Bread, Butter
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 35:
# Antecedents: Bread
# Consequents: Milk, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 34:
# Antecedents: Milk
# Consequents: Bread, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 29:
# Antecedents: Bread
# Consequents: Cookies, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 28:
# Antecedents: Cookies
# Consequents: Bread, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 23:
# Antecedents: Bread
# Consequents: Milk, Butter
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
#
#
# Rule 9:
# Antecedents: Cookies
# Consequents: Butter
# Support: 0.375
# Confidence: 0.500
# Lift: 0.800
# Leverage: -0.094
# Conviction: 0.750
#
#
# Rule 42:
# Antecedents: Milk
# Consequents: Cookies, Eggs
# Support: 0.375
# Confidence: 0.500
# Lift: 1.000
# Leverage: 0.000
# Conviction: 1.000
